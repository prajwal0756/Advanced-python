# %% [markdown]
# # 🏬 Retail Automated Analytics Pipeline

# %% [markdown]
# The retail company wants to automate daily sales analytics to monitor revenue, customer behavior, and product performance. Currently, reports are manual and delayed.<br>
# Objectives:
# 1. Automate daily sales aggregation
# 2. Track KPIs
# 3. Store structured data in warehouse
# 4. Generate automated reports
