# %%
import requests
from pprint import pprint

# %%
# Example API
url = "https://jsonplaceholder.typicode.com/posts/1" 

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    pprint(data)
else:
    print("Error")
# Out:
# {'body': 'quia et suscipit\n'
#          'suscipit recusandae consequuntur expedita et cum\n'
#          'reprehenderit molestiae ut ut quas totam\n'
#          'nostrum rerum est autem sunt rem eveniet architecto',
#  'id': 1,
#  'title': 'sunt aut facere repellat provident occaecati excepturi optio '
#           'reprehenderit',
#  'userId': 1}

# %%
import requests
url = "https://jsonplaceholder.typicode.com/posts"
payload = {"title": "Test", "body": "Hello API", "userId": 1}
response = requests.post(url, json=payload)
print(response.json())
# Out:
# {'title': 'Test', 'body': 'Hello API', 'userId': 1, 'id': 101}

# %%
import requests
from pprint import pprint
api_key = "your_api_key"
city="Dharan"
url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric"

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    pprint(data)
else:
    print(response.status_code)
# Out:
# 401

# %%
pip install zeep
# Out:
# Collecting zeep
#   Downloading zeep-4.3.2-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: attrs>=17.2.0 in /opt/anaconda3/envs/advpy/lib/python3.10/site-packages (from zeep) (25.4.0)
# Collecting isodate>=0.5.4 (from zeep)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting lxml>=4.6.0 (from zeep)
#   Downloading lxml-6.0.2-cp310-cp310-macosx_10_9_universal2.whl.metadata (3.6 kB)
# Requirement already satisfied: platformdirs>=1.4.0 in /opt/anaconda3/envs/advpy/lib/python3.10/site-packages (from zeep) (4.5.0)
# Requirement already satisfied: requests>=2.7.0 in /opt/anaconda3/envs/advpy/lib/python3.10/site-packages (from zeep) (2.32.5)
# Collecting requests-toolbelt>=0.7.1 (from zeep)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting requests-file>=1.5.1 (from zeep)
#   Downloading requests_file-3.0.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pytz in /opt/anaconda3/envs/advpy/lib/python3.10/site-packages (from zeep) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/advpy/lib/python3.10/site-packages (from requests>=2.7.0->zeep) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/advpy/lib/python3.10/site-packages (from requests>=2.7.0->zeep) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/advpy/lib/python3.10/site-packages (from requests>=2.7.0->zeep) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/advpy/lib/python3.10/site-packages (from requests>=2.7.0->zeep) (2025.11.12)
# Downloading zeep-4.3.2-py3-none-any.whl (101 kB)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading lxml-6.0.2-cp310-cp310-macosx_10_9_universal2.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 17.7 MB/s  0:00:007.9 MB/s eta 0:00:01
# Downloading requests_file-3.0.1-py2.py3-none-any.whl (4.5 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: lxml, isodate, requests-toolbelt, requests-file, zeep
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [zeep]━━━━━━ 4/5 [zeep]
# Successfully installed isodate-0.7.2 lxml-6.0.2 requests-file-3.0.1 requests-toolbelt-1.0.0 zeep-4.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from zeep import client
#wsdl url

wsdl = "https://www.dneonline.com/calculator.asmx?WSDL"
client = client(wsdl=wsdl)

#call a soap method
result = client.service.Add(10,20)
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       2 #wsdl url
#       4 wsdl = "https://www.dneonline.com/calculator.asmx?WSDL"
# ----> 5 client = client(wsdl=wsdl)
#       7 #call a soap method
#       8 result = client.service.Add(10,20)
#
# TypeError: 'module' object is not callable

# %%
api_key ="1e679f6aa64bfb3ba0dff937661"
city ="Dharan"
url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&unit=metric"
response = requests.get(url)
if response.status_code==200:
    data = response.json()
    print(data)
else:
    print("Error in the API call")
# Out:
# Error in the API call

# %%
import pandas as pd
from pandas import json_normalize
df = json_normalize(data)
df_weather =df[['weather','main.temp','main.humidity','wind.speed','name']].copy()
df_weather['Description'] = df_weather['weather'].apply(lambda x: x[0]['description'])
df_weather = df_weather.drop(columns=['weather'])
print(df_weather)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 4
#       2 from pandas import json_normalize
#       3 df = json_normalize(data)
# ----> 4 df_weather =df[['weather','main.temp','main.humidity','wind.speed','name']].copy()
#       5 df_weather['Description'] = df_weather['weather'].apply(lambda x: x[0]['description'])
#       6 df_weather = df_weather.drop(columns=['weather'])
#
# File /opt/anaconda3/envs/advpy/lib/python3.10/site-packages/pandas/core/frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/anaconda3/envs/advpy/lib/python3.10/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File /opt/anaconda3/envs/advpy/lib/python3.10/site-packages/pandas/core/indexes/base.py:6261, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6259 if nmissing:
#    6260     if nmissing == len(indexer):
# -> 6261         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6264     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['weather', 'main.temp', 'main.humidity', 'wind.speed', 'name'], dtype='object')] are in the [columns]"

# %%
import pandas as pd 
from pandas import json_normalize

df = json_normalize(data)
df_weather = df[[
    'name',
    'main.temp',
    'main.humidity',
    'main.feels_like',
    'wind.speed',
    'weather'
]].copy()


df_weather['Description'] = df['weather'].apply(lambda x:x[0]['description'])
df_weather = df_weather.drop(columns=['weather'])
print(df_weather)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 import pandas as pd
#       2 from pandas import json_normalize
# ----> 4 df = json_normalize(data)
#       5 df_weather = df[[
#       6     'name',
#       7     'main.temp',
#    (...)     11     'weather'
#      12 ]].copy()
#      15 df_weather['Description'] = df['weather'].apply(lambda x:x[0]['description'])
#
# NameError: name 'data' is not defined

# %%
import requests
import pandas as pd 
from pandas import json_normalize

api_key = "your_api_key"
cities=["Dharan", "Biratnagar", "Kathmandu", "Itahari", "Pokhara"]
df_list = []
for city in cities:
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric"

    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        df = json_normalize(data)
        df_weather = df[[
            'name',
            'main.temp',
            'main.humidity',
            'main.feels_like',
            'wind.speed',
            'weather'
        ]].copy()

        df_weather['Description'] = df['weather'].apply(lambda x:x[0]['description'])
        df_weather = df_weather.drop(columns=['weather'])
        df_list.append(df_weather)

final_df = pd.concat(df_list, ignore_index=True)
final_df.to_csv("weather_data.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 import requests
# ----> 2 import pandas as pd
#       3 from pandas import json_normalize
#       5 api_key = "your_api_key"
#
# ModuleNotFoundError: No module named 'pandas'
