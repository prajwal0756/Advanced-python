# %%
# !pip install requests beautifulsoup4
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from bs4 import BeautifulSoup

# %%
with open(file='index.html',mode='r') as f:
    doc = BeautifulSoup(f,'html.parser')
    print(doc.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    Document
#   </title>
#  </head>
#  <body>
#   <h1>
#    this is the heading 1
#   </h1>
#   <h1>
#    this is second h1
#   </h1>
#   <h2>
#    this is heading 2
#   </h2>
#   <p>
#    This is the pargraph tag $ 200
#    <a href="htpp://www.google.com">
#    </a>
#   </p>
#   <p>
#    Nvidia $3000;
#   </p>
#  </body>
# </html>

# %%
title= doc.title
print(title)
doc.title='hiii'
print(doc.title)
# Out:
# <title>Document</title>
# hiii

# %%
data=doc.find('h1')
print(data)
# Out:
# <h1>
#         this is the heading 1
#     </h1>

# %%
data=doc.find_all('h1')
print(data)
# Out:
# [<h1>
#         this is the heading 1
#     </h1>, <h1>
#         this is second h1
#     </h1>]

# %%
data=doc.find_all('h1')
for val in data:
    print(data)
# Out:
# [<h1>
#         this is the heading 1
#     </h1>, <h1>
#         this is second h1
#     </h1>]
# [<h1>
#         this is the heading 1
#     </h1>, <h1>
#         this is second h1
#     </h1>]

# %%
data=doc.find_all('p',string='This')

print(data)
# Out:
# []

# %%
import requests
from bs4 import BeautifulSoup

# %%
url='https://onlinekhabar.com'
response = requests.get(url)
if response.status_code ==200:
    sou = BeautifulSoup(response.text,'html.parser')
    print(sou.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://gmpg.org/xfn/11" rel="profile"/>
#   <meta content="108349739223556" property="fb:pages">
#    <meta content="366639890155270" property="fb:app_id">
#     <title>
#      Online Khabar – No 1 News Portal from Nepal in Nepali. – No 1 News Portal from Nepal in Nepali.
#     </title>
#     <meta content="max-image-preview:large" name="robots"/>
#     <link href="https://www.onlinekhabar.com/feed" rel="alternate" title="Online Khabar » Feed" type="application/rss+xml">
#      <link href="https://www.onlinekhabar.com/comments/feed" rel="alternate" title="Online Khabar » Comments Feed" type="application/rss+xml"/>
#      <link href="https://www.onlinekhabar.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.onlinekhabar.com%2F" rel="alternate" title="oEmbed (JSON)" type="application/json+oembed"/>
# ...

# %%
data= sou.find_all('h2')
print(data)
# Out:
# [<h2>
#                 ट्रेन्डिङ <span class="close-drawer">+</span>
# </h2>, <h2>
#                 ताजा अपडेट <span class="close-drawer">+</span>
# </h2>, <h2 class="ok-news-title-txt">हामी किन रुन्छौं ? तीन प्रकारका हुन्छन् आँसु</h2>, <h2 class="ok-news-title-txt">दाभोस बैठकको सुभारम्भमा नागरिक समाजले उठायो असमानताविरुद्ध आवाज</h2>, <h2 class="ok-news-title-txt">गर्भवती कुकुरलाई स्लिपिङ ट्याब्लेट खुवाउँदै लगातार यौनजन्य दुर्व्यवहार</h2>, <h2 class="ok-news-title-txt">खैरो हेरोइनसहित एक जना पक्राउ</h2>, <h2 class="ok-news-title-txt">अस्ट्रेलियाको न्यू साउथ वेल्समा गोली चल्दा तीन जनाको मृत्यु</h2>, <h2 class="ok-news-title-txt">इन्टरनेट स्पीडमा नयाँ कीर्तिमान, आँखा झिमिक्क पार्दा १ सय वटा  फिल्म डाउनलोड</h2>, <h2 class="ok-news-title-txt">सापकोटाको ‘यात्राको लय’ सार्वजनिक</h2>, <h2 class="ok-news-title-txt">‘बीपी र गिरिजाको जस्तो निष्ठा देखेर बालेनको सिपाही बनेँ’</h2>, <h2 class="ok-news-title-txt">मेरो प्यारो ओखलढुंगा (तस्वीरहरू)</h2>, <h2>
# ...

# %%
import pandas as pd
news=[]
for tag in sou.find_all(['h2','h3']):
    a=tag.find("a")
    if a and a.get('href'):
        title= a.get_text(strip=True)
        link=a['href']
        if title:
            news.append(
                {
                    'headline':title,
                    'link':link
                }
            )
df = pd.DataFrame(news)
df.drop_duplicates(subset='headline').reset_index(drop=True)
df.to_csv('links.csv',index=False)

# %%
url='https://en.wikipedia.org/wiki/Donald_Trump'
response = requests.get(url)
if response.status_code ==200:
    soup = BeautifulSoup(response.text,'html.parser')
    print(soup.prettify())
else:
    print('Respnse = ',response.status_code)
# Out:
# Respnse =  403

# %% [markdown]
# Chunckig and lazy evaluation important for exam
# (how to handle large datset)
#
# install
