# %%
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 811.7/811.7 kB 6.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pymongo]━━━ 1/2 [pymongo]
# ...

# %%
from pymongo import MongoClient

uri = "mongodb+srv://pukar_db_user:pukarkarki@cluster0.izfasmj.mongodb.net/?appName=Cluster0"
client = MongoClient(uri)
db = client["school"] # This is a database
collection = db["students"] # This is a collection which resembles a table

print(client.list_database_names())
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[3], line 8
#       5 db = client["school"] # This is a database
#       6 collection = db["students"] # This is a collection which resembles a table
# ----> 8 print(client.list_database_names())
#
# File /opt/anaconda3/envs/advpy/lib/python3.10/site-packages/pymongo/synchronous/mongo_client.py:2387, in MongoClient.list_database_names(self, session, comment)
#    2370 def list_database_names(
#    2371     self,
#    2372     session: Optional[client_session.ClientSession] = None,
#    2373     comment: Optional[Any] = None,
#    2374 ) -> list[str]:
#    2375     """Get a list of the names of all databases on the connected server.
#    2376
#    2377     :param session: a
#    (...)
#    2385     .. versionadded:: 3.6
#    2386     """
# -> 2387     res = self._list_databases(session, nameOnly=True, comment=comment)
# ...

# %%
# Insert a single document
student = {"name": "Alice", "age":25, "subjects":["Math", "Science"]}
collection.insert_one(student)
# Out:
# InsertOneResult(ObjectId('69553c3a5740c1d4d1cceca7'), acknowledged=True)

# %%
many_students = [
    {"name": "Ram", "age":18, "subjects":["Math", "Science"]},
    {"name": "Shyam", "age":27, "subjects":["Math", "Science"]}
]
collection.insert_many(many_students)
# Out:
# InsertManyResult([ObjectId('69553c3c5740c1d4d1cceca8'), ObjectId('69553c3c5740c1d4d1cceca9')], acknowledged=True)

# %%
# Query to display all students
for data in collection.find():
    print(data)
# Out:
# {'_id': ObjectId('69553c3a5740c1d4d1cceca7'), 'name': 'Alice', 'age': 25, 'subjects': ['Math', 'Science']}
# {'_id': ObjectId('69553c3c5740c1d4d1cceca8'), 'name': 'Ram', 'age': 18, 'subjects': ['Math', 'Science']}
# {'_id': ObjectId('69553c3c5740c1d4d1cceca9'), 'name': 'Shyam', 'age': 27, 'subjects': ['Math', 'Science']}

# %%
# Query to display conditional results
for data in collection.find({"age" : {"$gt" : 20}}):
    print(data)
# Out:
# {'_id': ObjectId('69553c3a5740c1d4d1cceca7'), 'name': 'Alice', 'age': 25, 'subjects': ['Math', 'Science']}
# {'_id': ObjectId('69553c3c5740c1d4d1cceca9'), 'name': 'Shyam', 'age': 27, 'subjects': ['Math', 'Science']}

# %%
print(db.list_collection_names())

collection.drop()

print(db.list_collection_names())
# Out:
# ['students']
# []

# %%
print(client.list_database_names())

client.drop_database("school")

print(client.list_database_names())
# Out:
# ['admin', 'confession', 'config', 'local']
# ['admin', 'confession', 'config', 'local']

# %%
import requests
from pprint import pprint

# %%
# Example API
url = "https://jsonplaceholder.typicode.com/posts/1" 

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    pprint(data)
else:
    print("Error")
# Out:
# {'body': 'quia et suscipit\n'
#          'suscipit recusandae consequuntur expedita et cum\n'
#          'reprehenderit molestiae ut ut quas totam\n'
#          'nostrum rerum est autem sunt rem eveniet architecto',
#  'id': 1,
#  'title': 'sunt aut facere repellat provident occaecati excepturi optio '
#           'reprehenderit',
#  'userId': 1}
