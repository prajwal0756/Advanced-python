# %% [markdown]
# ### Reading a JSON File

# %%
import json 
from pprint import pprint

with open("data.json", mode="r") as f:
    content = json.load(f)

pprint(content)
# Out:
# {'age': 30, 'name': 'Ram', 'skills': ['ML', 'Python']}

# %% [markdown]
# ### Writing a JSON File

# %%
import json 
from pprint import pprint

data = {'age': 30, 'name': 'Ram', 'skills': ["ML'", 'Python']}

with open("new.json", mode="w") as f:
    content = json.dump(data, f, indent=4)

# %% [markdown]
# ### Reading a JSON File using Pandas

# %%
import pandas as pd 

df = pd.read_json("data.json")

print(df)
# Out:
#   name  age  skills
# 0  Ram   30      ML
# 1  Ram   30  Python

# %% [markdown]
# ### Using SQLite

# %%
import sqlite3

conn = sqlite3.connect("example.db")
cursor = conn.cursor()

# %%
# Create table
cursor.execute("""
    CREATE TABLE IF NOT EXISTS students(
               id INTEGER PRIMARY KEY,
               name TEXT,
               age INTEGER,
               address TEXT
               )
               """)

# %%
# Insert Data
cursor.execute("INSERT INTO students (name,age,address) VALUES (?, ?, ?)",
        ("Ram", 25, "Biratnagar"))
conn.commit()

# %%
# Insert Data
cursor.execute("INSERT INTO students (name,age,address) VALUES (?, ?, ?)",
        ("Shyam", 25, "Biratnagar"))
conn.commit()

# %%
# Insert Data
cursor.execute("INSERT INTO students (name,age,address) VALUES (?, ?, ?)",
        ("Hari", 25, "Biratnagar"))
conn.commit()

# %%
# Query
cursor.execute("SELECT * FROM students")
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, 'Ram', 25, 'Biratnagar')
# (2, 'Shyam', 25, 'Biratnagar')
# (3, 'Hari', 25, 'Biratnagar')
# (4, 'Krishna', 25, 'Itahari')
# (5, 'Ram', 25, 'Biratnagar')
# (6, 'Shyam', 25, 'Biratnagar')
# (7, 'Hari', 25, 'Biratnagar')

# %%
# Insert Data
cursor.execute("INSERT INTO students (name,age,address) VALUES (?, ?, ?)",
        ("Krishna", 25, "Itahari"))
conn.commit()

# %%
# Query
cursor.execute("SELECT * FROM students")
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, 'Ram', 25, 'Biratnagar')
# (2, 'Shyam', 25, 'Biratnagar')
# (3, 'Hari', 25, 'Biratnagar')
# (4, 'Krishna', 25, 'Itahari')
# (5, 'Ram', 25, 'Biratnagar')
# (6, 'Shyam', 25, 'Biratnagar')
# (7, 'Hari', 25, 'Biratnagar')
# (8, 'Krishna', 25, 'Itahari')

# %%
# Query
cursor.execute('SELECT * FROM students WHERE name LIKE "R%"')
rows = cursor.fetchall()
for row in rows:
    print(row)
conn.close()
# Out:
# (1, 'Ram', 25, 'Biratnagar')
# (5, 'Ram', 25, 'Biratnagar')

# %%
from sqlalchemy import create_engine

engine = create_engine('sqlite:///mydb.db', echo=True)

# %%
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String

Base = declarative_base()

class Student(Base):
    __tablename__ = 'students'
    id = Column(Integer, primary_key=True)
    name = Column(String)
    age = Column(Integer)

# Create the table
Base.metadata.create_all(engine)
# Out:
# 2025-12-29 13:32:29,898 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-29 13:32:29,898 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("students")
# 2025-12-29 13:32:29,899 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-29 13:32:29,899 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("students")
# 2025-12-29 13:32:29,900 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-12-29 13:32:29,900 INFO sqlalchemy.engine.Engine
# CREATE TABLE students (
# 	id INTEGER NOT NULL,
# 	name VARCHAR,
# 	age INTEGER,
# 	PRIMARY KEY (id)
# )
#
#
# 2025-12-29 13:32:29,901 INFO sqlalchemy.engine.Engine [no key 0.00036s] ()
# 2025-12-29 13:32:29,902 INFO sqlalchemy.engine.Engine COMMIT
# /var/folders/5d/v4623g510hs5f3dknp9j4g2r0000gp/T/ipykernel_69062/2342944549.py:4: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %%
from sqlalchemy.orm import sessionmaker

Session = sessionmaker(bind=engine)
session = Session()

# %%
# Adding data
student1 = Student(name='Ram', age=25)
student2 = Student(name='Shyam', age=25)
session.add(student1)
session.add(student2)
session.commit()
# Out:
# 2025-12-29 13:32:29,912 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-29 13:32:29,914 INFO sqlalchemy.engine.Engine INSERT INTO students (name, age) VALUES (?, ?) RETURNING id
# 2025-12-29 13:32:29,914 INFO sqlalchemy.engine.Engine [generated in 0.00007s (insertmanyvalues) 1/2 (ordered; batch not supported)] ('Ram', 25)
# 2025-12-29 13:32:29,915 INFO sqlalchemy.engine.Engine INSERT INTO students (name, age) VALUES (?, ?) RETURNING id
# 2025-12-29 13:32:29,916 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/2 (ordered; batch not supported)] ('Shyam', 25)
# 2025-12-29 13:32:29,917 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Get all students
students = session.query(Student).all()
for s in students:
    print(s.name, s.age)
# Out:
# 2025-12-29 13:33:24,956 INFO sqlalchemy.engine.Engine SELECT students.id AS students_id, students.name AS students_name, students.age AS students_age
# FROM students
# 2025-12-29 13:33:24,957 INFO sqlalchemy.engine.Engine [cached since 16.42s ago] ()
# Ram 25
# Shyam 25
